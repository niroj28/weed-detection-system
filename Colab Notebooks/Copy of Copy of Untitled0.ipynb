# %%
# %pip install ultralytics
import ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.5/586.5 kB 15.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 kB 21.9 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/ultralytics
# Out:
# /content/drive/MyDrive/Colab_Notebooks/ultralytics

# %%
# %pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=10 imgsz=512 plots=True
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.11 torch-2.0.0+cu118 CPU
# ...

# %%
model = YOLO('yolov8.pt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-506067dc33f3> in <cell line: 1>()
# ----> 1 model = YOLO('yolov8.pt')
#       2
#
# NameError: name 'YOLO' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
