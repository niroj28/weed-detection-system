# %%
# %cd /content/drive/MyDrive/Colab_Notebooks
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab_Notebooks'
# /content
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab_Notebooks/yolov5'
# /content
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-620d8d1af4f7> in <cell line: 5>()
#       3
#       4 import torch
# ----> 5 import utils
#
# ModuleNotFoundError: No module named 'utils'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install clearml

# %%
# !python train.py --img 640 --batch 20 --epochs 100 --data custom_data.yaml --weights yolov5s.pt --cache

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/Colab_Notebooks/weeds02.mp4
