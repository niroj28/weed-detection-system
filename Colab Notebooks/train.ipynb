# %%
# %pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#
# ...

# %%
# %cd D:/YOLOv8 train/ultralytics
# Out:
# D:\YOLOv8 train\ultralytics

# %%
# %pip install -qr requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=100 imgsz=512 plots=True
# Out:
# ^C

# %%
# %cd D:/YOLOv8 train
# Out:
# D:\YOLOv8 train

# %%
model = YOLO('yolov8.pt')  # load a custom model

# Predict with the model
results = model('D:/YOLOv8 train/train_data/train/images/agri_0_3.jpeg' ,save=True, imgsz=512, conf=0.5)  # predict on an image
# Out:
# image 1/1 D:\YOLOv8 train\train_data\train\images\agri_0_3.jpeg: 512x512 1 Crop, 327.1ms
# Speed: 1.2ms preprocess, 327.1ms inference, 2.3ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs\detect\predict
